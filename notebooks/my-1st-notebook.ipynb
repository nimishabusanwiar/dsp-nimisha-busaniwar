# %%
# !pip install numpy
import numpy as np
from IPython.display import display

my_array = np.random.randint(0, 100, size=(10, 3))
display(my_array)
# Out:
# ...
# array([[73, 85, 63],
#        [83, 68, 24],
#        [61, 44, 20],
#        [20, 31, 98],
#        [59, 74, 99],
#        [59,  9, 44],
#        [25,  1,  4],
#        [13, 91, 81],
#        [84, 54, 50],
#        [50, 95, 17]])
